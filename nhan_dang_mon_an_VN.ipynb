# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyentuyetnhung/btap-nhan-dang-AI-/blob/main/nhan_dang_mon_an_VN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cài đặt thư viện cần thiết
# !pip install -q gradio
# !pip install -q tensorflow

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
import numpy as np
from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pickle
import gradio as gr
import matplotlib.pyplot as plt

BASE_DIR = "/content/drive/MyDrive/nhandangdoan"
IMG_SIZE = (60, 60)
BATCH_SIZE = 128
EPOCHS = 300
RANDOM_STATE = 42


CANONICAL_CLASSES = ['banh chung', 'com tam', 'pho', 'banh mi']
CANONICAL_EMOJIS = ['🍚', '🍛', '🍜', '🥖']
CANONICAL_EMOJI_MAP = dict(zip(CANONICAL_CLASSES, CANONICAL_EMOJIS))

LABEL_ENCODER_PATH = os.path.join(BASE_DIR, 'label_encoder.pkl')
FINAL_MODEL_PATH = os.path.join(BASE_DIR, 'final_model.h5')


def is_image_file(filename):
    ext = filename.lower().rsplit('.', 1)
    if len(ext) == 2:
        return ext[1] in ('jpg', 'jpeg', 'png', 'bmp', 'gif', 'tiff', 'webp')
    return False

def load_data(data_dir, class_names, img_size=IMG_SIZE):
    images = []
    labels = []

    for class_name in class_names:
        class_dir = os.path.join(data_dir, class_name)
        if not os.path.isdir(class_dir):
            print(f"[Warning] Thư mục không tồn tại: {class_dir} (bỏ qua)")
            continue

        for img_name in os.listdir(class_dir):
            if not is_image_file(img_name):
                continue
            img_path = os.path.join(class_dir, img_name)
            try:
                img = Image.open(img_path).convert('RGB')
                img = img.resize(img_size)
                img_array = np.array(img, dtype=np.float32) / 255.0

                images.append(img_array)
                labels.append(class_name)
            except Exception as e:
                print(f"Lỗi đọc ảnh {img_path}: {e}")

    if len(images) == 0:
        raise ValueError(f"Không tìm thấy ảnh trong {data_dir}. Kiểm tra đường dẫn và tên thư mục lớp.")

    return np.array(images), np.array(labels)

print("Đang tải dữ liệu từ:", BASE_DIR)
try:
    X, y = load_data(BASE_DIR, CANONICAL_CLASSES, IMG_SIZE)
    print(f"Tổng ảnh: {len(X)}")

    unique, counts = np.unique(y, return_counts=True)
    print("Số lượng theo lớp:")
    for u, c in zip(unique, counts):
        print(f"  - {u}: {c} ảnh")

    missing = [c for c in CANONICAL_CLASSES if c not in unique]
    if missing:
        print(f"[Lưu ý] Không tìm thấy ảnh cho các lớp: {missing}")

except Exception as e:
    print(f"Lỗi khi tải dữ liệu: {e}")
    print("Tạo dữ liệu mẫu để demo...")

    X = np.random.rand(40, IMG_SIZE[0], IMG_SIZE[1], 3).astype(np.float32)
    y = np.array(['banh chung']*10 + ['com tam']*10 + ['pho']*10 + ['banh mi']*10)


label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
num_classes = len(label_encoder.classes_)

X_flat = X.reshape(X.shape[0], IMG_SIZE[0] * IMG_SIZE[1] * 3)
y_categorical = to_categorical(y_encoded, num_classes=num_classes)

# Lưu label encoder
with open(LABEL_ENCODER_PATH, 'wb') as f:
    pickle.dump({'label_encoder': label_encoder, 'trained_classes': label_encoder.classes_.tolist()}, f)
print(f"Đã lưu label encoder -> {LABEL_ENCODER_PATH}")


min_count = np.min(np.bincount(y_encoded)) if len(y_encoded) > 0 else 0
if min_count < 2:
    print('[Warning] Ít hơn 2 ảnh cho một hoặc nhiều lớp. Sẽ không dùng stratify để chia dữ liệu.')
    stratify_param = None
else:
    stratify_param = y_encoded

x_train, x_test, y_train, y_test = train_test_split(
    X_flat, y_categorical, test_size=0.2, random_state=RANDOM_STATE, stratify=stratify_param
)

print(f"Kích thước train: {x_train.shape}, test: {x_test.shape}")

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(IMG_SIZE[0]*IMG_SIZE[1]*3,)))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

model.compile(
    optimizer="rmsprop",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

print("Bắt đầu huấn luyện...")
history = model.fit(
    x_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(x_test, y_test),
    verbose=1
)

model.save(FINAL_MODEL_PATH)
print(f"Đã lưu mô hình cuối cùng -> {FINAL_MODEL_PATH}")


print("Đang đánh giá trên tập test...")
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Độ chính xác trên tập test: {test_acc:.4f}")

try:
    with open(LABEL_ENCODER_PATH, 'rb') as f:
        le_data = pickle.load(f)
        label_encoder = le_data['label_encoder']
        trained_classes = le_data.get('trained_classes', label_encoder.classes_.tolist())
except:
    print("Không thể load label encoder, sử dụng encoder hiện tại")
    trained_classes = label_encoder.classes_.tolist()


emoji_map = {c: CANONICAL_EMOJI_MAP.get(c, '🍽️') for c in trained_classes}


def predict_image(img):
    if img is None:
        return "<p style='color: red;'>Không có ảnh được tải lên.</p>"

    try:
        img_proc = img.resize(IMG_SIZE).convert('RGB')
        arr = np.array(img_proc, dtype=np.float32) / 255.0

        arr_flat = arr.reshape(1, IMG_SIZE[0] * IMG_SIZE[1] * 3)

        preds = model.predict(arr_flat, verbose=0)
        pred_idx = int(np.argmax(preds, axis=1)[0])


        class_name = label_encoder.inverse_transform([pred_idx])[0]
        confidence = float(np.max(preds))

        # Lấy emoji (nếu có)
        emoji = emoji_map.get(class_name, '🍽️')

        # Gradient màu theo độ tin cậy
        if confidence > 0.7:
            color_gradient = "linear-gradient(135deg, #43e97b 0%, #38f9d7 100%)"
        elif confidence > 0.5:
            color_gradient = "linear-gradient(135deg, #fa709a 0%, #fee140 100%)"
        else:
            color_gradient = "linear-gradient(135deg, #ff5858 0%, #f09819 100%)"


        per_class_html = ""
        for i, cname in enumerate(label_encoder.classes_):
            cemoji = emoji_map.get(cname, '🍽️')
            per_class_html += f"<p style=\"margin:5px 0;font-size:14px;\">{cemoji} {cname}: {preds[0][i]:.2%}</p>"

        result = f"""
        <div style="text-align: center; padding: 25px; background: {color_gradient};
                    border-radius: 20px; color: white; box-shadow: 0 10px 30px rgba(0,0,0,0.2);">
            <h2 style="margin: 0; font-size: 28px; font-weight: bold;">{emoji} {class_name}</h2>
            <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 15px; margin: 15px 0;">
                <p style="margin: 0; font-size: 20px;">Độ tin cậy: <strong>{confidence:.2%}</strong></p>
            </div>
            <div style="background: rgba(0,0,0,0.1); padding: 10px; border-radius: 10px;">
                <p style="margin: 0; font-size: 16px;">Xác suất cho các món:</p>
                {per_class_html}
            </div>
        </div>
        """

        return result

    except Exception as e:
        return f"<p style='color:red;'>Lỗi khi dự đoán: {str(e)}</p>"


css = """
body {background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); min-height: 100vh; margin: 0; padding: 20px;}
.gr-box {background: rgba(255, 255, 255, 0.95) !important; border-radius: 20px !important; padding: 25px !important;
         box-shadow: 0 15px 35px rgba(0, 0, 0, 0.2) !important; border: none !important;}
.gr-button {background: linear-gradient(135deg, #6a11cb 0%, #2575fc 100%) !important; color: white !important;
            border: none !important; border-radius: 10px !important; padding: 15px 30px !important;
            font-size: 18px !important; font-weight: bold !important; transition: all 0.3s ease !important;
            cursor: pointer !important; margin-top: 15px !important;}
.gr-button:hover {transform: translateY(-3px) !important; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.3) !important;}
.footer {text-align: center; margin-top: 30px; color: rgba(255,255,255,0.7); font-size: 0.9em;}
.instructions {background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); padding: 20px; border-radius: 15px; color: white; margin-bottom: 20px;}
"""

with gr.Blocks(css=css, theme=gr.themes.Soft()) as demo:
    gr.Markdown(
        """
        # 🍜 Nhận Diện Món Ăn Việt Nam
        <div style="text-align: center; color: #555; margin-bottom: 20px; font-size: 18px;">
            Ứng dụng trí tuệ nhân tạo nhận diện các món ăn Việt Nam
        </div>
        """
    )

    with gr.Row():
        with gr.Column(scale=1, min_width=300):
            gr.Markdown("### 📸 Tải lên hình ảnh món ăn")
            image_input = gr.Image(type="pil", label="", height=300)
            predict_btn = gr.Button("🔍 Nhận diện món ăn")

            gr.Markdown("### 🍽️ Món ăn được hỗ trợ")
            for i, cls in enumerate(CANONICAL_CLASSES):
                gr.Markdown(f"{CANONICAL_EMOJIS[i]} **{cls}**")

        with gr.Column(scale=1, min_width=300):
            gr.Markdown("### 🔍 Kết quả nhận diện")
            output_html = gr.HTML()

    with gr.Row():
        with gr.Accordion("📖 Hướng dẫn sử dụng", open=False):
            gr.Markdown("""
            1. **Tải lên hình ảnh**: Click vào khung ảnh hoặc kéo thả ảnh vào
            2. **Nhận diện**: Nhấn nút "Nhận diện món ăn"
            3. **Xem kết quả**: Kết quả sẽ hiển thị ở khung bên phải

            **Lưu ý**: Ảnh càng rõ nét thì kết quả càng chính xác!
            """)

    predict_btn.click(fn=predict_image, inputs=image_input, outputs=output_html)

    gr.Markdown(
        f"""
        <div class="footer">
            Ứng dụng nhận diện món ăn Việt Nam | Sử dụng mạng ANN | Độ chính xác (test): {test_acc*100:.2f}%
        </div>
        """
    )

# Chạy giao diện
print("Giao diện nhận diện món ăn đã sẵn sàng!")
try:
    demo.launch(share=True, debug=True)
except Exception as e:
    print(f"Lỗi khi khởi chạy Gradio: {e}")
    print("Thử chạy với cờ share=False...")
    demo.launch(share=False, debug=True)
# Out:
# Mounted at /content/drive
# Đang tải dữ liệu từ: /content/drive/MyDrive/nhandangdoan
# Tổng ảnh: 84
# Số lượng theo lớp:
#   - banh chung: 21 ảnh
#   - banh mi: 21 ảnh
#   - com tam: 21 ảnh
#   - pho: 21 ảnh
# Đã lưu label encoder -> /content/drive/MyDrive/nhandangdoan/label_encoder.pkl
# Kích thước train: (67, 10800), test: (17, 10800)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │     5,530,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,662,468 (21.60 MB)
#  Trainable params: 5,662,468 (21.60 MB)
#  Non-trainable params: 0 (0.00 B)
# Bắt đầu huấn luyện...
# Epoch 1/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.2239 - loss: 1.5422 - val_accuracy: 0.2353 - val_loss: 44.6154
# Epoch 2/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.2537 - loss: 37.7691 - val_accuracy: 0.2353 - val_loss: 57.5526
# Epoch 3/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.2687 - loss: 50.9392 - val_accuracy: 0.2941 - val_loss: 33.9173
# Epoch 4/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.2388 - loss: 36.6423 - val_accuracy: 0.2353 - val_loss: 22.3417
# Epoch 5/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.2537 - loss: 20.0093 - val_accuracy: 0.2353 - val_loss: 9.4074
# Epoch 6/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.3134 - loss: 8.9655 - val_accuracy: 0.2353 - val_loss: 9.8555
# Epoch 7/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.2537 - loss: 11.6761 - val_accuracy: 0.2353 - val_loss: 6.2692
# Epoch 8/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.3433 - loss: 6.9617 - val_accuracy: 0.2941 - val_loss: 1.7380
# Epoch 9/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.2687 - loss: 3.9002 - val_accuracy: 0.2941 - val_loss: 1.6548
# Epoch 10/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.3881 - loss: 4.0294 - val_accuracy: 0.2941 - val_loss: 2.1728
# Epoch 11/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.2687 - loss: 2.7492 - val_accuracy: 0.2941 - val_loss: 1.5313
# Epoch 12/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.2687 - loss: 3.3465 - val_accuracy: 0.2353 - val_loss: 2.3339
# Epoch 13/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4030 - loss: 2.6109 - val_accuracy: 0.2353 - val_loss: 2.5891
# Epoch 14/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.3731 - loss: 3.1002 - val_accuracy: 0.2941 - val_loss: 2.0908
# Epoch 15/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.4030 - loss: 2.5893 - val_accuracy: 0.2353 - val_loss: 1.6356
# Epoch 16/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.3134 - loss: 1.8826 - val_accuracy: 0.2941 - val_loss: 1.7215
# Epoch 17/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.3134 - loss: 1.8669 - val_accuracy: 0.2941 - val_loss: 1.6154
# Epoch 18/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.2537 - loss: 2.5699 - val_accuracy: 0.2941 - val_loss: 2.2246
# Epoch 19/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.3582 - loss: 2.1195 - val_accuracy: 0.3529 - val_loss: 1.8983
# Epoch 20/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.4627 - loss: 1.9921 - val_accuracy: 0.2941 - val_loss: 1.9888
# Epoch 21/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.3284 - loss: 2.0674 - val_accuracy: 0.2353 - val_loss: 1.7608
# Epoch 22/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.4179 - loss: 1.6781 - val_accuracy: 0.3529 - val_loss: 1.5983
# Epoch 23/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.3731 - loss: 1.7165 - val_accuracy: 0.2353 - val_loss: 1.4090
# Epoch 24/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.3881 - loss: 1.3995 - val_accuracy: 0.2941 - val_loss: 1.5550
# Epoch 25/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.3582 - loss: 1.5226 - val_accuracy: 0.3529 - val_loss: 1.4846
# Epoch 26/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.5672 - loss: 1.2639 - val_accuracy: 0.3529 - val_loss: 1.9039
# Epoch 27/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.4179 - loss: 1.8192 - val_accuracy: 0.1765 - val_loss: 1.7444
# Epoch 28/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.4030 - loss: 1.5789 - val_accuracy: 0.3529 - val_loss: 1.5175
# Epoch 29/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.3731 - loss: 1.4332 - val_accuracy: 0.2353 - val_loss: 2.1394
# Epoch 30/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.3284 - loss: 1.9450 - val_accuracy: 0.2941 - val_loss: 2.2393
# Epoch 31/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.2985 - loss: 2.4009 - val_accuracy: 0.2353 - val_loss: 1.6385
# Epoch 32/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.5075 - loss: 1.3193 - val_accuracy: 0.3529 - val_loss: 1.3953
# Epoch 33/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.3881 - loss: 1.3245 - val_accuracy: 0.1765 - val_loss: 1.5559
# Epoch 34/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.4328 - loss: 1.4090 - val_accuracy: 0.3529 - val_loss: 1.4352
# Epoch 35/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.5075 - loss: 1.2344 - val_accuracy: 0.2941 - val_loss: 1.4183
# Epoch 36/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.4925 - loss: 1.2797 - val_accuracy: 0.2353 - val_loss: 1.5730
# Epoch 37/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.5075 - loss: 1.2859 - val_accuracy: 0.2941 - val_loss: 1.6915
# Epoch 38/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.4179 - loss: 1.4818 - val_accuracy: 0.4118 - val_loss: 1.4413
# Epoch 39/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step - accuracy: 0.4776 - loss: 1.2558 - val_accuracy: 0.2941 - val_loss: 1.4735
# Epoch 40/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.4776 - loss: 1.1459 - val_accuracy: 0.4118 - val_loss: 1.4477
# Epoch 41/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.5373 - loss: 1.1101 - val_accuracy: 0.2941 - val_loss: 1.4966
# Epoch 42/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.4627 - loss: 1.1100 - val_accuracy: 0.2941 - val_loss: 1.3826
# Epoch 43/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.4328 - loss: 1.2881 - val_accuracy: 0.4118 - val_loss: 1.4667
# Epoch 44/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.5522 - loss: 1.2227 - val_accuracy: 0.2353 - val_loss: 1.4774
# Epoch 45/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.4925 - loss: 1.2748 - val_accuracy: 0.2353 - val_loss: 2.3147
# Epoch 46/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.3731 - loss: 1.9076 - val_accuracy: 0.3529 - val_loss: 2.0932
# Epoch 47/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.3582 - loss: 1.9676 - val_accuracy: 0.2941 - val_loss: 1.5848
# Epoch 48/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.4328 - loss: 1.4022 - val_accuracy: 0.2353 - val_loss: 1.4534
# Epoch 49/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.3284 - loss: 1.3890 - val_accuracy: 0.4706 - val_loss: 1.3015
# Epoch 50/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.4925 - loss: 1.1593 - val_accuracy: 0.3529 - val_loss: 1.4057
# Epoch 51/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.4776 - loss: 1.1681 - val_accuracy: 0.4706 - val_loss: 1.3173
# Epoch 52/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.5821 - loss: 1.0490 - val_accuracy: 0.4118 - val_loss: 1.2976
# Epoch 53/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5224 - loss: 1.0925 - val_accuracy: 0.3529 - val_loss: 1.2928
# Epoch 54/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.5821 - loss: 1.0655 - val_accuracy: 0.2941 - val_loss: 1.3464
# Epoch 55/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.5672 - loss: 0.9774 - val_accuracy: 0.5294 - val_loss: 1.2991
# Epoch 56/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.4925 - loss: 1.0942 - val_accuracy: 0.2941 - val_loss: 1.3805
# Epoch 57/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.5224 - loss: 1.0927 - val_accuracy: 0.4118 - val_loss: 1.4172
# Epoch 58/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.5373 - loss: 1.1616 - val_accuracy: 0.3529 - val_loss: 1.5081
# Epoch 59/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.3582 - loss: 1.3396 - val_accuracy: 0.4706 - val_loss: 1.3908
# Epoch 60/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.6269 - loss: 1.0090 - val_accuracy: 0.5882 - val_loss: 1.2953
# Epoch 61/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5373 - loss: 1.0261 - val_accuracy: 0.3529 - val_loss: 1.7405
# Epoch 62/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4478 - loss: 1.2849 - val_accuracy: 0.3529 - val_loss: 1.5998
# Epoch 63/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.4179 - loss: 1.5321 - val_accuracy: 0.1765 - val_loss: 1.4424
# Epoch 64/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.4776 - loss: 1.1813 - val_accuracy: 0.4118 - val_loss: 1.2979
# Epoch 65/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.5373 - loss: 1.0014 - val_accuracy: 0.2941 - val_loss: 1.4478
# Epoch 66/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.4627 - loss: 1.2350 - val_accuracy: 0.2941 - val_loss: 1.6495
# Epoch 67/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.4925 - loss: 1.2031 - val_accuracy: 0.3529 - val_loss: 1.3193
# Epoch 68/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6567 - loss: 0.8812 - val_accuracy: 0.4118 - val_loss: 1.2551
# Epoch 69/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.6418 - loss: 0.8353 - val_accuracy: 0.2941 - val_loss: 1.3678
# Epoch 70/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.5373 - loss: 1.0239 - val_accuracy: 0.4706 - val_loss: 1.2794
# Epoch 71/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.6418 - loss: 0.9312 - val_accuracy: 0.5294 - val_loss: 1.3569
# Epoch 72/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.5970 - loss: 0.9317 - val_accuracy: 0.4118 - val_loss: 1.6364
# Epoch 73/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.5075 - loss: 1.3094 - val_accuracy: 0.2941 - val_loss: 1.7326
# Epoch 74/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.5522 - loss: 1.4939 - val_accuracy: 0.2353 - val_loss: 1.4034
# Epoch 75/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.5373 - loss: 1.0898 - val_accuracy: 0.3529 - val_loss: 1.4854
# Epoch 76/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.5522 - loss: 1.0946 - val_accuracy: 0.2941 - val_loss: 1.6733
# Epoch 77/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.4925 - loss: 1.3303 - val_accuracy: 0.3529 - val_loss: 1.5030
# Epoch 78/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.5075 - loss: 1.1330 - val_accuracy: 0.4118 - val_loss: 1.4254
# Epoch 79/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.5672 - loss: 0.9983 - val_accuracy: 0.4118 - val_loss: 1.3019
# Epoch 80/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.5075 - loss: 1.0915 - val_accuracy: 0.4118 - val_loss: 1.3642
# Epoch 81/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.5970 - loss: 0.9313 - val_accuracy: 0.4706 - val_loss: 1.4083
# Epoch 82/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.6567 - loss: 0.8943 - val_accuracy: 0.3529 - val_loss: 1.5099
# Epoch 83/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.5224 - loss: 0.9975 - val_accuracy: 0.3529 - val_loss: 1.4908
# Epoch 84/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.4328 - loss: 1.1938 - val_accuracy: 0.5882 - val_loss: 1.2368
# Epoch 85/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.5821 - loss: 1.0072 - val_accuracy: 0.4118 - val_loss: 1.3911
# Epoch 86/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.5075 - loss: 1.0407 - val_accuracy: 0.4118 - val_loss: 1.2578
# Epoch 87/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.5821 - loss: 0.8893 - val_accuracy: 0.3529 - val_loss: 1.2957
# Epoch 88/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.7463 - loss: 0.6971 - val_accuracy: 0.4118 - val_loss: 1.3083
# Epoch 89/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.5821 - loss: 1.0021 - val_accuracy: 0.2353 - val_loss: 1.6553
# Epoch 90/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6418 - loss: 0.8160 - val_accuracy: 0.4706 - val_loss: 1.5283
# Epoch 91/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.5821 - loss: 1.0254 - val_accuracy: 0.2941 - val_loss: 1.5545
# Epoch 92/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 903ms/step - accuracy: 0.5970 - loss: 1.0245 - val_accuracy: 0.4118 - val_loss: 1.4894
# Epoch 93/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step - accuracy: 0.5373 - loss: 1.1024 - val_accuracy: 0.4118 - val_loss: 1.2826
# Epoch 94/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step - accuracy: 0.6567 - loss: 0.8160 - val_accuracy: 0.4118 - val_loss: 1.3565
# Epoch 95/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.6866 - loss: 0.8472 - val_accuracy: 0.4706 - val_loss: 1.2695
# Epoch 96/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.6119 - loss: 0.9161 - val_accuracy: 0.5294 - val_loss: 1.3661
# Epoch 97/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.7612 - loss: 0.7584 - val_accuracy: 0.4118 - val_loss: 1.5487
# Epoch 98/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5522 - loss: 1.2149 - val_accuracy: 0.2941 - val_loss: 1.4029
# Epoch 99/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.5970 - loss: 0.9546 - val_accuracy: 0.4118 - val_loss: 1.3028
# Epoch 100/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7164 - loss: 0.7975 - val_accuracy: 0.3529 - val_loss: 1.3883
# Epoch 101/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7313 - loss: 0.7204 - val_accuracy: 0.4118 - val_loss: 1.4004
# Epoch 102/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.6269 - loss: 0.7804 - val_accuracy: 0.4118 - val_loss: 1.4472
# Epoch 103/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.5821 - loss: 0.9064 - val_accuracy: 0.2941 - val_loss: 2.2525
# Epoch 104/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4627 - loss: 1.4687 - val_accuracy: 0.4118 - val_loss: 1.7765
# Epoch 105/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.4925 - loss: 1.3779 - val_accuracy: 0.3529 - val_loss: 1.4731
# Epoch 106/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.5970 - loss: 0.8978 - val_accuracy: 0.2941 - val_loss: 1.7111
# Epoch 107/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.4478 - loss: 1.4016 - val_accuracy: 0.2941 - val_loss: 1.4890
# Epoch 108/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6269 - loss: 1.0773 - val_accuracy: 0.4118 - val_loss: 1.2679
# Epoch 109/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.7164 - loss: 0.8386 - val_accuracy: 0.4706 - val_loss: 1.2796
# Epoch 110/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.6866 - loss: 0.7558 - val_accuracy: 0.4706 - val_loss: 1.2102
# Epoch 111/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.6418 - loss: 0.7427 - val_accuracy: 0.4706 - val_loss: 1.2390
# Epoch 112/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.7463 - loss: 0.6366 - val_accuracy: 0.3529 - val_loss: 1.3176
# Epoch 113/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8060 - loss: 0.5897 - val_accuracy: 0.3529 - val_loss: 1.2843
# Epoch 114/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.6866 - loss: 0.7346 - val_accuracy: 0.2941 - val_loss: 1.4521
# Epoch 115/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.6866 - loss: 0.7722 - val_accuracy: 0.4706 - val_loss: 1.2497
# Epoch 116/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.7910 - loss: 0.6008 - val_accuracy: 0.4118 - val_loss: 1.3394
# Epoch 117/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.7313 - loss: 0.6480 - val_accuracy: 0.3529 - val_loss: 1.4439
# Epoch 118/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.6418 - loss: 0.7918 - val_accuracy: 0.3529 - val_loss: 1.4537
# Epoch 119/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.6866 - loss: 0.7543 - val_accuracy: 0.2941 - val_loss: 1.3960
# Epoch 120/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.7015 - loss: 0.7097 - val_accuracy: 0.4706 - val_loss: 1.2101
# Epoch 121/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8209 - loss: 0.6036 - val_accuracy: 0.2941 - val_loss: 1.3858
# Epoch 122/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.7463 - loss: 0.6428 - val_accuracy: 0.4706 - val_loss: 1.3562
# Epoch 123/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.6567 - loss: 0.6935 - val_accuracy: 0.3529 - val_loss: 1.5018
# Epoch 124/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6418 - loss: 0.8340 - val_accuracy: 0.3529 - val_loss: 1.7606
# Epoch 125/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6418 - loss: 1.0182 - val_accuracy: 0.3529 - val_loss: 2.0149
# Epoch 126/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.5224 - loss: 1.4430 - val_accuracy: 0.2941 - val_loss: 2.0876
# Epoch 127/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.4925 - loss: 1.4998 - val_accuracy: 0.2941 - val_loss: 1.9135
# Epoch 128/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.5075 - loss: 1.2536 - val_accuracy: 0.2941 - val_loss: 1.9727
# Epoch 129/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.4030 - loss: 1.5667 - val_accuracy: 0.2353 - val_loss: 1.7882
# Epoch 130/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.5075 - loss: 1.3115 - val_accuracy: 0.5294 - val_loss: 1.4057
# Epoch 131/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.7761 - loss: 0.6641 - val_accuracy: 0.4118 - val_loss: 1.3402
# Epoch 132/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.7910 - loss: 0.5838 - val_accuracy: 0.4118 - val_loss: 1.4539
# Epoch 133/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.7910 - loss: 0.5764 - val_accuracy: 0.4118 - val_loss: 1.2749
# Epoch 134/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.8060 - loss: 0.5336 - val_accuracy: 0.4118 - val_loss: 1.2673
# Epoch 135/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step - accuracy: 0.8209 - loss: 0.5299 - val_accuracy: 0.5294 - val_loss: 1.4165
# Epoch 136/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8060 - loss: 0.5062 - val_accuracy: 0.4118 - val_loss: 1.2699
# Epoch 137/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.7761 - loss: 0.5304 - val_accuracy: 0.4118 - val_loss: 1.4357
# Epoch 138/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.7612 - loss: 0.6288 - val_accuracy: 0.4118 - val_loss: 1.4715
# Epoch 139/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.7463 - loss: 0.5386 - val_accuracy: 0.4118 - val_loss: 1.3211
# Epoch 140/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step - accuracy: 0.7910 - loss: 0.5039 - val_accuracy: 0.4118 - val_loss: 1.3198
# Epoch 141/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8358 - loss: 0.4659 - val_accuracy: 0.4706 - val_loss: 1.4128
# Epoch 142/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7761 - loss: 0.4415 - val_accuracy: 0.4118 - val_loss: 1.2989
# Epoch 143/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8507 - loss: 0.4374 - val_accuracy: 0.4118 - val_loss: 1.4664
# Epoch 144/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8358 - loss: 0.4386 - val_accuracy: 0.3529 - val_loss: 1.8552
# Epoch 145/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7612 - loss: 0.5637 - val_accuracy: 0.2353 - val_loss: 2.1142
# Epoch 146/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.6418 - loss: 1.1699 - val_accuracy: 0.4118 - val_loss: 1.6996
# Epoch 147/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.7015 - loss: 0.6727 - val_accuracy: 0.2941 - val_loss: 1.3298
# Epoch 148/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.7910 - loss: 0.6773 - val_accuracy: 0.3529 - val_loss: 1.6302
# Epoch 149/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.7612 - loss: 0.6103 - val_accuracy: 0.4706 - val_loss: 1.3901
# Epoch 150/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8209 - loss: 0.4507 - val_accuracy: 0.3529 - val_loss: 1.5193
# Epoch 151/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.7612 - loss: 0.5576 - val_accuracy: 0.4706 - val_loss: 1.2248
# Epoch 152/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7612 - loss: 0.5565 - val_accuracy: 0.4118 - val_loss: 1.3503
# Epoch 153/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.8209 - loss: 0.3941 - val_accuracy: 0.4118 - val_loss: 1.4599
# Epoch 154/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.7910 - loss: 0.4348 - val_accuracy: 0.4118 - val_loss: 1.5632
# Epoch 155/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.8060 - loss: 0.4734 - val_accuracy: 0.4118 - val_loss: 1.3839
# Epoch 156/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8358 - loss: 0.4976 - val_accuracy: 0.3529 - val_loss: 1.4688
# Epoch 157/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8209 - loss: 0.4608 - val_accuracy: 0.4118 - val_loss: 1.3722
# Epoch 158/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.8209 - loss: 0.4423 - val_accuracy: 0.4118 - val_loss: 1.4259
# Epoch 159/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.7463 - loss: 0.6006 - val_accuracy: 0.4118 - val_loss: 1.7287
# Epoch 160/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.7015 - loss: 0.6434 - val_accuracy: 0.2941 - val_loss: 1.5326
# Epoch 161/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.6567 - loss: 0.6763 - val_accuracy: 0.4706 - val_loss: 1.6115
# Epoch 162/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.7761 - loss: 0.4741 - val_accuracy: 0.2941 - val_loss: 1.5760
# Epoch 163/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.6866 - loss: 0.7366 - val_accuracy: 0.3529 - val_loss: 1.8353
# Epoch 164/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.6866 - loss: 0.7548 - val_accuracy: 0.4118 - val_loss: 1.1490
# Epoch 165/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.8806 - loss: 0.5102 - val_accuracy: 0.4118 - val_loss: 1.4275
# Epoch 166/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - accuracy: 0.8806 - loss: 0.3694 - val_accuracy: 0.5294 - val_loss: 1.5196
# Epoch 167/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8209 - loss: 0.4086 - val_accuracy: 0.2353 - val_loss: 1.7607
# Epoch 168/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7612 - loss: 0.6983 - val_accuracy: 0.4118 - val_loss: 1.6952
# Epoch 169/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.8060 - loss: 0.5277 - val_accuracy: 0.2941 - val_loss: 2.5968
# Epoch 170/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.6567 - loss: 1.2054 - val_accuracy: 0.3529 - val_loss: 2.5619
# Epoch 171/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.5224 - loss: 2.4834 - val_accuracy: 0.2353 - val_loss: 2.0451
# Epoch 172/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.5970 - loss: 1.0449 - val_accuracy: 0.3529 - val_loss: 1.2820
# Epoch 173/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8358 - loss: 0.5264 - val_accuracy: 0.3529 - val_loss: 1.3167
# Epoch 174/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8358 - loss: 0.4586 - val_accuracy: 0.5294 - val_loss: 1.2512
# Epoch 175/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9104 - loss: 0.4083 - val_accuracy: 0.4118 - val_loss: 1.4441
# Epoch 176/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8358 - loss: 0.3962 - val_accuracy: 0.3529 - val_loss: 1.4013
# Epoch 177/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.8955 - loss: 0.2934 - val_accuracy: 0.4118 - val_loss: 1.4675
# Epoch 178/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8955 - loss: 0.2473 - val_accuracy: 0.3529 - val_loss: 1.4271
# Epoch 179/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9254 - loss: 0.2323 - val_accuracy: 0.4118 - val_loss: 1.5560
# Epoch 180/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.8657 - loss: 0.2978 - val_accuracy: 0.4118 - val_loss: 1.4904
# Epoch 181/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.8657 - loss: 0.3048 - val_accuracy: 0.4118 - val_loss: 1.7472
# Epoch 182/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.8507 - loss: 0.3315 - val_accuracy: 0.4706 - val_loss: 2.0216
# Epoch 183/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.8358 - loss: 0.4643 - val_accuracy: 0.4706 - val_loss: 1.5203
# Epoch 184/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.8507 - loss: 0.4214 - val_accuracy: 0.5294 - val_loss: 1.5771
# Epoch 185/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 569ms/step - accuracy: 0.8358 - loss: 0.3800 - val_accuracy: 0.4118 - val_loss: 2.0362
# Epoch 186/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8358 - loss: 0.4639 - val_accuracy: 0.4706 - val_loss: 2.3906
# Epoch 187/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6418 - loss: 1.0907 - val_accuracy: 0.2941 - val_loss: 1.9412
# Epoch 188/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.6269 - loss: 0.8985 - val_accuracy: 0.3529 - val_loss: 1.3018
# Epoch 189/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.7761 - loss: 0.6447 - val_accuracy: 0.5294 - val_loss: 1.2264
# Epoch 190/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.8806 - loss: 0.4765 - val_accuracy: 0.4118 - val_loss: 1.2269
# Epoch 191/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.8955 - loss: 0.3366 - val_accuracy: 0.2941 - val_loss: 1.3859
# Epoch 192/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.8507 - loss: 0.3708 - val_accuracy: 0.3529 - val_loss: 1.3659
# Epoch 193/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9403 - loss: 0.2122 - val_accuracy: 0.4706 - val_loss: 1.5090
# Epoch 194/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.8358 - loss: 0.3563 - val_accuracy: 0.4118 - val_loss: 1.6392
# Epoch 195/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8657 - loss: 0.3196 - val_accuracy: 0.2941 - val_loss: 2.0177
# Epoch 196/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8358 - loss: 0.4417 - val_accuracy: 0.4118 - val_loss: 1.5053
# Epoch 197/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.8060 - loss: 0.3627 - val_accuracy: 0.3529 - val_loss: 1.3690
# Epoch 198/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9104 - loss: 0.2717 - val_accuracy: 0.4118 - val_loss: 1.5966
# Epoch 199/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.8358 - loss: 0.2928 - val_accuracy: 0.4706 - val_loss: 1.7244
# Epoch 200/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8358 - loss: 0.4034 - val_accuracy: 0.3529 - val_loss: 1.7920
# Epoch 201/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.7761 - loss: 0.5433 - val_accuracy: 0.4118 - val_loss: 1.4052
# Epoch 202/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9403 - loss: 0.2839 - val_accuracy: 0.4706 - val_loss: 1.6028
# Epoch 203/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8507 - loss: 0.2619 - val_accuracy: 0.4118 - val_loss: 1.5146
# Epoch 204/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8955 - loss: 0.2658 - val_accuracy: 0.3529 - val_loss: 1.6698
# Epoch 205/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7761 - loss: 0.4301 - val_accuracy: 0.4706 - val_loss: 1.6426
# Epoch 206/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7313 - loss: 0.5983 - val_accuracy: 0.3529 - val_loss: 2.0086
# Epoch 207/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.7463 - loss: 0.5881 - val_accuracy: 0.2941 - val_loss: 1.7593
# Epoch 208/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.6418 - loss: 0.8385 - val_accuracy: 0.4118 - val_loss: 2.6778
# Epoch 209/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7910 - loss: 0.7236 - val_accuracy: 0.3529 - val_loss: 2.6959
# Epoch 210/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5672 - loss: 1.6809 - val_accuracy: 0.2941 - val_loss: 3.2418
# Epoch 211/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.5821 - loss: 1.6442 - val_accuracy: 0.3529 - val_loss: 1.2942
# Epoch 212/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.7313 - loss: 0.6659 - val_accuracy: 0.3529 - val_loss: 1.3154
# Epoch 213/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9104 - loss: 0.3691 - val_accuracy: 0.3529 - val_loss: 1.4466
# Epoch 214/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.8657 - loss: 0.3514 - val_accuracy: 0.3529 - val_loss: 1.4533
# Epoch 215/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8657 - loss: 0.3302 - val_accuracy: 0.4706 - val_loss: 1.5495
# Epoch 216/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9254 - loss: 0.2004 - val_accuracy: 0.3529 - val_loss: 1.4614
# Epoch 217/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9552 - loss: 0.2140 - val_accuracy: 0.4118 - val_loss: 1.4327
# Epoch 218/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9254 - loss: 0.1928 - val_accuracy: 0.3529 - val_loss: 1.5201
# Epoch 219/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9701 - loss: 0.1538 - val_accuracy: 0.4118 - val_loss: 1.6067
# Epoch 220/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9254 - loss: 0.1918 - val_accuracy: 0.4118 - val_loss: 1.6334
# Epoch 221/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.8806 - loss: 0.2435 - val_accuracy: 0.4706 - val_loss: 1.7133
# Epoch 222/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8806 - loss: 0.3494 - val_accuracy: 0.4706 - val_loss: 1.8295
# Epoch 223/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8657 - loss: 0.2653 - val_accuracy: 0.4706 - val_loss: 2.2700
# Epoch 224/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.8060 - loss: 0.5516 - val_accuracy: 0.4118 - val_loss: 1.9535
# Epoch 225/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.6716 - loss: 0.8159 - val_accuracy: 0.3529 - val_loss: 1.5887
# Epoch 226/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7612 - loss: 0.6115 - val_accuracy: 0.4706 - val_loss: 1.4202
# Epoch 227/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.7910 - loss: 0.5392 - val_accuracy: 0.4118 - val_loss: 1.8607
# Epoch 228/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.7612 - loss: 0.4957 - val_accuracy: 0.3529 - val_loss: 1.4047
# Epoch 229/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.8358 - loss: 0.3801 - val_accuracy: 0.2941 - val_loss: 1.4761
# Epoch 230/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.8209 - loss: 0.4222 - val_accuracy: 0.4118 - val_loss: 1.5185
# Epoch 231/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8657 - loss: 0.3333 - val_accuracy: 0.4118 - val_loss: 1.6823
# Epoch 232/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.8060 - loss: 0.4885 - val_accuracy: 0.4118 - val_loss: 1.8227
# Epoch 233/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.7463 - loss: 0.7230 - val_accuracy: 0.4118 - val_loss: 2.1878
# Epoch 234/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.7910 - loss: 0.6326 - val_accuracy: 0.4706 - val_loss: 1.7350
# Epoch 235/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7463 - loss: 0.8312 - val_accuracy: 0.4706 - val_loss: 2.0606
# Epoch 236/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6716 - loss: 0.9472 - val_accuracy: 0.4118 - val_loss: 2.0283
# Epoch 237/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.7612 - loss: 0.5352 - val_accuracy: 0.3529 - val_loss: 1.8736
# Epoch 238/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step - accuracy: 0.6866 - loss: 0.7742 - val_accuracy: 0.3529 - val_loss: 1.9521
# Epoch 239/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.7313 - loss: 0.9023 - val_accuracy: 0.4706 - val_loss: 1.4578
# Epoch 240/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.8358 - loss: 0.4412 - val_accuracy: 0.4118 - val_loss: 1.5335
# Epoch 241/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.8657 - loss: 0.3104 - val_accuracy: 0.4706 - val_loss: 1.5636
# Epoch 242/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.8657 - loss: 0.3910 - val_accuracy: 0.4118 - val_loss: 1.5240
# Epoch 243/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step - accuracy: 0.8955 - loss: 0.2361 - val_accuracy: 0.4118 - val_loss: 1.5215
# Epoch 244/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9254 - loss: 0.2275 - val_accuracy: 0.4118 - val_loss: 1.7073
# Epoch 245/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8955 - loss: 0.2377 - val_accuracy: 0.3529 - val_loss: 1.5550
# Epoch 246/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9403 - loss: 0.2159 - val_accuracy: 0.3529 - val_loss: 1.7122
# Epoch 247/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9254 - loss: 0.2062 - val_accuracy: 0.4118 - val_loss: 1.9079
# Epoch 248/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.8806 - loss: 0.2650 - val_accuracy: 0.3529 - val_loss: 1.6257
# Epoch 249/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8806 - loss: 0.3106 - val_accuracy: 0.4118 - val_loss: 1.7104
# Epoch 250/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9254 - loss: 0.1760 - val_accuracy: 0.3529 - val_loss: 1.7302
# Epoch 251/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8955 - loss: 0.2020 - val_accuracy: 0.4118 - val_loss: 1.6790
# Epoch 252/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9403 - loss: 0.1845 - val_accuracy: 0.4706 - val_loss: 1.8721
# Epoch 253/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.9104 - loss: 0.2209 - val_accuracy: 0.4118 - val_loss: 1.7371
# Epoch 254/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.8657 - loss: 0.2973 - val_accuracy: 0.4706 - val_loss: 1.6922
# Epoch 255/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8507 - loss: 0.3383 - val_accuracy: 0.4118 - val_loss: 1.7475
# Epoch 256/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8657 - loss: 0.3160 - val_accuracy: 0.4118 - val_loss: 2.0415
# Epoch 257/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9104 - loss: 0.1900 - val_accuracy: 0.3529 - val_loss: 1.6525
# Epoch 258/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.8806 - loss: 0.3205 - val_accuracy: 0.3529 - val_loss: 1.7890
# Epoch 259/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.8657 - loss: 0.3768 - val_accuracy: 0.3529 - val_loss: 2.1087
# Epoch 260/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.7910 - loss: 0.3982 - val_accuracy: 0.4706 - val_loss: 1.5342
# Epoch 261/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7313 - loss: 0.5681 - val_accuracy: 0.3529 - val_loss: 2.9127
# Epoch 262/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.6567 - loss: 0.7996 - val_accuracy: 0.3529 - val_loss: 2.2209
# Epoch 263/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.5821 - loss: 1.0609 - val_accuracy: 0.2353 - val_loss: 3.2324
# Epoch 264/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.4478 - loss: 1.8758 - val_accuracy: 0.2941 - val_loss: 3.1220
# Epoch 265/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.4925 - loss: 1.9543 - val_accuracy: 0.5294 - val_loss: 1.1248
# Epoch 266/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7463 - loss: 0.7138 - val_accuracy: 0.5882 - val_loss: 1.0775
# Epoch 267/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7463 - loss: 0.7069 - val_accuracy: 0.5294 - val_loss: 1.0824
# Epoch 268/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8358 - loss: 0.5354 - val_accuracy: 0.4118 - val_loss: 1.2186
# Epoch 269/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9403 - loss: 0.3880 - val_accuracy: 0.4118 - val_loss: 1.2413
# Epoch 270/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.8657 - loss: 0.4803 - val_accuracy: 0.5294 - val_loss: 1.2449
# Epoch 271/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9104 - loss: 0.3889 - val_accuracy: 0.4118 - val_loss: 1.3979
# Epoch 272/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9104 - loss: 0.3457 - val_accuracy: 0.4706 - val_loss: 1.3839
# Epoch 273/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8657 - loss: 0.4210 - val_accuracy: 0.4118 - val_loss: 1.3105
# Epoch 274/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9104 - loss: 0.3773 - val_accuracy: 0.3529 - val_loss: 1.4844
# Epoch 275/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.8806 - loss: 0.4234 - val_accuracy: 0.4118 - val_loss: 1.3983
# Epoch 276/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8806 - loss: 0.3809 - val_accuracy: 0.5294 - val_loss: 1.3177
# Epoch 277/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8507 - loss: 0.4456 - val_accuracy: 0.4118 - val_loss: 1.3607
# Epoch 278/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.7164 - loss: 0.4882 - val_accuracy: 0.4706 - val_loss: 1.1727
# Epoch 279/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.8955 - loss: 0.4425 - val_accuracy: 0.4118 - val_loss: 1.3015
# Epoch 280/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.8507 - loss: 0.4788 - val_accuracy: 0.3529 - val_loss: 1.5461
# Epoch 281/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7761 - loss: 0.5118 - val_accuracy: 0.4706 - val_loss: 1.7178
# Epoch 282/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.7761 - loss: 0.4812 - val_accuracy: 0.4118 - val_loss: 2.5526
# Epoch 283/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.6567 - loss: 0.8148 - val_accuracy: 0.2941 - val_loss: 2.2889
# Epoch 284/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6269 - loss: 0.9248 - val_accuracy: 0.3529 - val_loss: 2.1586
# Epoch 285/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.4478 - loss: 1.8151 - val_accuracy: 0.2941 - val_loss: 1.5298
# Epoch 286/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.7164 - loss: 0.7720 - val_accuracy: 0.3529 - val_loss: 1.2090
# Epoch 287/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.8806 - loss: 0.4360 - val_accuracy: 0.4118 - val_loss: 1.2657
# Epoch 288/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.8806 - loss: 0.4640 - val_accuracy: 0.4118 - val_loss: 1.3583
# Epoch 289/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.9254 - loss: 0.3364 - val_accuracy: 0.4118 - val_loss: 1.4670
# Epoch 290/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9851 - loss: 0.2279 - val_accuracy: 0.4706 - val_loss: 1.5152
# Epoch 291/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.9403 - loss: 0.2348 - val_accuracy: 0.4118 - val_loss: 1.7156
# Epoch 292/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9104 - loss: 0.3203 - val_accuracy: 0.4118 - val_loss: 1.5171
# Epoch 293/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.8955 - loss: 0.2907 - val_accuracy: 0.4118 - val_loss: 1.7255
# Epoch 294/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9851 - loss: 0.1990 - val_accuracy: 0.4118 - val_loss: 1.6434
# Epoch 295/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.9552 - loss: 0.3130 - val_accuracy: 0.4118 - val_loss: 1.6852
# Epoch 296/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8955 - loss: 0.2411 - val_accuracy: 0.4118 - val_loss: 1.7261
# Epoch 297/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9403 - loss: 0.2730 - val_accuracy: 0.4118 - val_loss: 1.5583
# Epoch 298/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9403 - loss: 0.2212 - val_accuracy: 0.3529 - val_loss: 2.0260
# Epoch 299/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.8955 - loss: 0.2688 - val_accuracy: 0.4118 - val_loss: 1.6939
# Epoch 300/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9254 - loss: 0.2858 - val_accuracy: 0.3529 - val_loss: 1.7956
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Đã lưu mô hình cuối cùng -> /content/drive/MyDrive/nhandangdoan/final_model.h5
# Đang đánh giá trên tập test...
# 1/1 - 0s - 48ms/step - accuracy: 0.3529 - loss: 1.7956
# Độ chính xác trên tập test: 0.3529
# Giao diện nhận diện món ăn đã sẵn sàng!
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://e5e01c7fdea225b2f9.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e5e01c7fdea225b2f9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
